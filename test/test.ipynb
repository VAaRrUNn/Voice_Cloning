# %%
import torch
import torch.nn as nn

# %%
model = nn.Sequential(
    nn.Linear(10, 20)
)

# %%
state_dict = model.state_dict()

# Save the state dict to a file
with open("tacotron2_weights.pth", "wb") as f:
    torch.save(state_dict, f)

# %%
weights2 = torch.load("tacotron2_weights.pth")
weights2
# Out:
# OrderedDict([('0.weight',
#               tensor([[-0.0501,  0.1029,  0.0657, -0.1336,  0.2281,  0.2265, -0.1950,  0.2623,
#                         0.1600,  0.2583],
#                       [-0.0708,  0.1795, -0.1065,  0.1361, -0.2025,  0.1408, -0.2649, -0.2487,
#                        -0.0084, -0.2879],
#                       [ 0.2192,  0.0044,  0.2918, -0.0474,  0.0126,  0.0528, -0.1775, -0.1559,
#                        -0.1860, -0.1977],
#                       [ 0.2727,  0.2186,  0.1478, -0.0651, -0.1374, -0.2791,  0.0095, -0.0927,
#                        -0.1396,  0.2780],
#                       [-0.1455,  0.0517, -0.2120,  0.2242,  0.2762, -0.2507, -0.0764,  0.1960,
#                        -0.2658, -0.1440],
#                       [-0.3042, -0.2671,  0.1667, -0.2452,  0.0990, -0.1299, -0.2863,  0.1694,
#                         0.2838,  0.3112],
#                       [ 0.2276, -0.1235, -0.1781,  0.0379,  0.1904, -0.0601, -0.2699,  0.2890,
#                         0.0449, -0.2090],
#                       [-0.2881, -0.1354, -0.2651,  0.1712,  0.2261,  0.1573, -0.1877, -0.0896,
#                        -0.0010, -0.2595],
#                       [-0.2134, -0.0995, -0.3086,  0.0058, -0.2448,  0.0269, -0.1821,  0.3079,
#                         0.2671,  0.0779],
#                       [-0.2614, -0.2818,  0.0213,  0.1858, -0.2055, -0.0547,  0.2157, -0.1436,
#                         0.0769, -0.0622],
#                       [ 0.1621, -0.1425,  0.0038, -0.0047, -0.1266, -0.2799,  0.1618, -0.1328,
#                        -0.0516,  0.1129],
#                       [-0.1699,  0.3007, -0.2791, -0.0673,  0.1933, -0.1734,  0.1973, -0.1203,
#                        -0.1806, -0.0935],
#                       [ 0.2350, -0.2628, -0.3009, -0.1676, -0.2762,  0.1756, -0.1177, -0.0209,
#                        -0.1585, -0.2946],
#                       [ 0.2522, -0.1142,  0.2489,  0.0457,  0.1932, -0.2808, -0.2366, -0.1224,
#                        -0.2062,  0.1426],
#                       [-0.1090, -0.0493,  0.2705, -0.1940,  0.2053, -0.2102, -0.0346, -0.2139,
#                        -0.2164,  0.1969],
#                       [ 0.1145,  0.3044, -0.0095, -0.0913, -0.2616,  0.2669, -0.2710,  0.2371,
#                         0.1876,  0.1255],
#                       [ 0.2123,  0.0031,  0.2734, -0.2429, -0.2413, -0.0268, -0.1792, -0.2526,
#                         0.0614,  0.2953],
#                       [ 0.2952, -0.2028, -0.0847,  0.1714,  0.1690,  0.1964, -0.0354,  0.1566,
#                         0.1299, -0.2144],
#                       [ 0.0977,  0.2881,  0.1599, -0.0742, -0.0536,  0.0183,  0.1087,  0.0960,
#                         0.1281, -0.1894],
#                       [ 0.0631, -0.0322, -0.1752, -0.1988,  0.0928, -0.1003, -0.2891, -0.0758,
#                        -0.2960,  0.0391]])),
#              ('0.bias',
#               tensor([-0.0914, -0.1732, -0.0296, -0.2462,  0.0757, -0.3091, -0.2179,  0.0972,
#                       -0.3089,  0.1979, -0.1414,  0.0044, -0.3039,  0.0040, -0.2497,  0.2512,
#                       -0.2230, -0.1272,  0.3099, -0.2685]))])

# %%
import torch
waveglow = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_waveglow', model_math='fp16')

weights = waveglow.state_dict()

with open("waveglow_weights.pth", "wb") as f:
    torch.save(state_dict, f)
